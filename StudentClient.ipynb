# %% [markdown]
# # Student Client
#
# ### Steps to Run with Reinforcement Agent.
# - 1. Add the RLAgent here
# - 2. Train the RLAgent/ You can train the RLAgent in some other notebook and store the results using pickle library in python. Then you can test your RLAgent with the server.
# - 3. Use the policy to run on the server.
#
# ### DO NOT TRAIN THE MODEL WHILE RUNNING ON THE SERVER!

# %%
import pickle

# %%
def greedy(Q, s):
    return np.argmax(Q[s])

# %%
import socket
import os
import subprocess
import ast
import pdb
import numpy as np
import time
player = 'amandlek' #enter unique name for your game
s = socket.socket() 
# s.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)
host = '100.24.254.170' # change ip addres to ip address of your computer or use 'localhost' to practice
port = 9999

with (open("dict.pickle", "rb")) as openfile:
    while True:
        try:
            Q = pickle.load(openfile)
        except EOFError:
            break

            
s.connect((host, port))
while True:
    data = s.recv(1024)
    if data.decode("utf-8") == 'send':
        s.send(str.encode( player))
        client_response = str(s.recv(20480), "utf-8")
        print(client_response, end="")
        break

while True:
    data = s.recv(20480)
    print(data,end=".")
    if data.decode("utf-8") == f'sendinfo':
        s.send(str.encode("acknowledged_pick"))
        ##Here you will recieve information about the player such as card rank, card suit, stash score,
        print(data.decode("utf-8"))
        #sts = player['CardSuit']
        print(data.decode("utf-8"))
        client_response = str(s.recv(20480), "utf-8")
        print(client_response)
        z=np.random.randint(0, 1)
        action = greedy(Q, z)
        print("action pick ",action)
        s.send(str.encode( str(action)))
    if data.decode("utf-8") == f'sendaction_for_card_drop':
        s.send(str.encode("acknowledged_drop"))
        ro=str(s.recv(20480), "utf-8")
        ro=ast.literal_eval(ro)
        print("action send for drop")
        print(ro)
        #follow same procedure as abov to send observations to your agent
        ###### Look at the above observations and action in variable action#####
        z=np.random.randint(0, 1)
        action = greedy(Q, z)
        s.send(str.encode( str(action)))
        print("action drop",action)
    if data.decode("utf-8") == 'gameover':
        print("Game over wait for others to play and wait for results")
        break
    if data.decode("utf-8") == 'round_over':
        s.send(str.encode("acknowledged_round_over"))
        print('Round over')
        client_response = str(s.recv(20480), "utf-8")
        print(client_response, end="")
# Out:
# Connection established, Names collectedb'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 13, 'CardSuit': [6, 1, 6], 'CardRanks': ['S', 'D', 'C'], 'PileRank': 'A', 'PileSuit': 'S'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 14, 'CardSuit': [6, 1, 6, 1], 'CardRanks': ['S', 'D', 'C', 'S'], 'PileRank': '6', 'PileSuit': 'H'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 8, 'CardSuit': [1, 6, 1], 'CardRanks': ['D', 'C', 'S'], 'PileRank': '7', 'PileSuit': 'C'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 15, 'CardSuit': [1, 6, 1, 7], 'CardRanks': ['D', 'C', 'S', 'C'], 'PileRank': '4', 'PileSuit': 'S'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 14, 'CardSuit': [6, 1, 7], 'CardRanks': ['C', 'S', 'C'], 'PileRank': '3', 'PileSuit': 'S'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 17, 'CardSuit': [6, 1, 7, 3], 'CardRanks': ['C', 'S', 'C', 'S'], 'PileRank': 'A', 'PileSuit': 'D'}
# action drop 0
# b'round_over'.Round over
# Player: comp3  Score: 10 Stash Score : 10
# Player: amandlek  Score: 11 Stash Score : 11
# Player: comp2  Score: 0 Stash Score : 0
# Player: mrashid1  Score: 19 Stash Score : 19
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 12, 'CardSuit': [2, 6, 4], 'CardRanks': ['S', 'H', 'C'], 'PileRank': '4', 'PileSuit': 'S'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 16, 'CardSuit': [2, 6, 4, 4], 'CardRanks': ['S', 'H', 'C', 'S'], 'PileRank': '3', 'PileSuit': 'H'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 14, 'CardSuit': [6, 4, 4], 'CardRanks': ['H', 'C', 'S'], 'PileRank': '7', 'PileSuit': 'S'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 21, 'CardSuit': [6, 4, 4, 7], 'CardRanks': ['H', 'C', 'S', 'S'], 'PileRank': '5', 'PileSuit': 'C'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 15, 'CardSuit': [4, 4, 7], 'CardRanks': ['C', 'S', 'S'], 'PileRank': '4', 'PileSuit': 'D'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 7, 'CardSuit': [7], 'CardRanks': ['S'], 'PileRank': '6', 'PileSuit': 'S'}
# action drop 0
# b'round_over'.Round over
# Player: comp2  Score: 16 Stash Score : 16
# Player: comp3  Score: 21 Stash Score : 11
# Player: mrashid1  Score: 23 Stash Score : 4
# Player: amandlek  Score: 11 Stash Score : 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 15, 'CardSuit': [3, 5, 7], 'CardRanks': ['S', 'S', 'D'], 'PileRank': '2', 'PileSuit': 'C'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 17, 'CardSuit': [3, 5, 7, 2], 'CardRanks': ['S', 'S', 'D', 'C'], 'PileRank': '5', 'PileSuit': 'D'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 14, 'CardSuit': [5, 7, 2], 'CardRanks': ['S', 'D', 'C'], 'PileRank': '4', 'PileSuit': 'D'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 18, 'CardSuit': [5, 7, 2, 4], 'CardRanks': ['S', 'D', 'C', 'D'], 'PileRank': 'A', 'PileSuit': 'C'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 13, 'CardSuit': [7, 2, 4], 'CardRanks': ['D', 'C', 'D'], 'PileRank': '7', 'PileSuit': 'H'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 20, 'CardSuit': [7, 2, 4, 7], 'CardRanks': ['D', 'C', 'D', 'H'], 'PileRank': '2', 'PileSuit': 'D'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 13, 'CardSuit': [2, 4, 7], 'CardRanks': ['C', 'D', 'H'], 'PileRank': '6', 'PileSuit': 'D'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 19, 'CardSuit': [2, 4, 7, 6], 'CardRanks': ['C', 'D', 'H', 'D'], 'PileRank': '6', 'PileSuit': 'C'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 17, 'CardSuit': [4, 7, 6], 'CardRanks': ['D', 'H', 'D'], 'PileRank': '3', 'PileSuit': 'H'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 20, 'CardSuit': [4, 7, 6, 3], 'CardRanks': ['D', 'H', 'D', 'H'], 'PileRank': 'A', 'PileSuit': 'D'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 16, 'CardSuit': [7, 6, 3], 'CardRanks': ['H', 'D', 'H'], 'PileRank': '4', 'PileSuit': 'C'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 20, 'CardSuit': [7, 6, 3, 4], 'CardRanks': ['H', 'D', 'H', 'C']}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 13, 'CardSuit': [6, 3, 4], 'CardRanks': ['D', 'H', 'C'], 'PileRank': '5', 'PileSuit': 'C'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 18, 'CardSuit': [6, 3, 4, 5], 'CardRanks': ['D', 'H', 'C', 'C'], 'PileRank': '7', 'PileSuit': 'C'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 12, 'CardSuit': [3, 4, 5], 'CardRanks': ['H', 'C', 'C'], 'PileRank': '4', 'PileSuit': 'S'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 16, 'CardSuit': [3, 4, 5, 4], 'CardRanks': ['H', 'C', 'C', 'S'], 'PileRank': '6', 'PileSuit': 'D'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 13, 'CardSuit': [4, 5, 4], 'CardRanks': ['C', 'C', 'S'], 'PileRank': '4', 'PileSuit': 'D'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 5, 'CardSuit': [5], 'CardRanks': ['C'], 'PileRank': '6', 'PileSuit': 'D'}
# action drop 0
# b'round_over'.Round over
# Player: mrashid1  Score: 28 Stash Score : 5
# Player: comp3  Score: 30 Stash Score : 9
# Player: comp2  Score: 31 Stash Score : 15
# Player: amandlek  Score: 11 Stash Score : 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 16, 'CardSuit': [7, 7, 2], 'CardRanks': ['H', 'S', 'H'], 'PileRank': '2', 'PileSuit': 'D'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 18, 'CardSuit': [7, 7, 2, 2], 'CardRanks': ['H', 'S', 'H', 'D']}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 11, 'CardSuit': [7, 2, 2], 'CardRanks': ['S', 'H', 'D'], 'PileRank': '4', 'PileSuit': 'S'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 15, 'CardSuit': [7, 2, 2, 4], 'CardRanks': ['S', 'H', 'D', 'S'], 'PileRank': '7', 'PileSuit': 'D'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 8, 'CardSuit': [2, 2, 4], 'CardRanks': ['H', 'D', 'S'], 'PileRank': '2', 'PileSuit': 'C'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 4, 'CardSuit': [4], 'CardRanks': ['S'], 'PileRank': '3', 'PileSuit': 'D'}
# action drop 0
# b'round_over'.Round over
# Player: amandlek  Score: 11 Stash Score : 0
# Player: comp3  Score: 39 Stash Score : 9
# Player: comp2  Score: 43 Stash Score : 12
# Player: mrashid1  Score: 41 Stash Score : 13
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 19, 'CardSuit': [6, 7, 6], 'CardRanks': ['S', 'D', 'H'], 'PileRank': 'A', 'PileSuit': 'D'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 20, 'CardSuit': [6, 7, 6, 1], 'CardRanks': ['S', 'D', 'H', 'D'], 'PileRank': '5', 'PileSuit': 'C'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 14, 'CardSuit': [7, 6, 1], 'CardRanks': ['D', 'H', 'D'], 'PileRank': '2', 'PileSuit': 'D'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 16, 'CardSuit': [7, 6, 1, 2], 'CardRanks': ['D', 'H', 'D', 'D'], 'PileRank': '6', 'PileSuit': 'C'}
# action drop 0
# b'round_over'.Round over
# Player: comp3  Score: 57 Stash Score : 18
# Player: comp2  Score: 47 Stash Score : 4
# Player: mrashid1  Score: 41 Stash Score : 0
# Player: amandlek  Score: 20 Stash Score : 9
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 17, 'CardSuit': [6, 4, 7], 'CardRanks': ['H', 'S', 'S'], 'PileRank': '6', 'PileSuit': 'C'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 23, 'CardSuit': [6, 4, 7, 6], 'CardRanks': ['H', 'S', 'S', 'C'], 'PileRank': 'A', 'PileSuit': 'S'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 17, 'CardSuit': [4, 7, 6], 'CardRanks': ['S', 'S', 'C'], 'PileRank': '7', 'PileSuit': 'H'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 24, 'CardSuit': [4, 7, 6, 7], 'CardRanks': ['S', 'S', 'C', 'H'], 'PileRank': 'A', 'PileSuit': 'H'}
# action drop 0
# b'round_over'.Round over
# Player: comp3  Score: 57 Stash Score : 0
# Player: amandlek  Score: 40 Stash Score : 20
# Player: mrashid1  Score: 48 Stash Score : 7
# Player: comp2  Score: 61 Stash Score : 14
# b'round_over'.Round over
# Player: comp2  Score: 75 Stash Score : 14
# Player: mrashid1  Score: 48 Stash Score : 0
# Player: amandlek  Score: 49 Stash Score : 9
# Player: comp3  Score: 75 Stash Score : 18
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 12, 'CardSuit': [1, 6, 5], 'CardRanks': ['D', 'D', 'S'], 'PileRank': '7', 'PileSuit': 'D'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 19, 'CardSuit': [1, 6, 5, 7], 'CardRanks': ['D', 'D', 'S', 'D'], 'PileRank': '5', 'PileSuit': 'C'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 18, 'CardSuit': [6, 5, 7], 'CardRanks': ['D', 'S', 'D'], 'PileRank': '3', 'PileSuit': 'H'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 21, 'CardSuit': [6, 5, 7, 3], 'CardRanks': ['D', 'S', 'D', 'H'], 'PileRank': '3', 'PileSuit': 'C'}
# action drop 0
# b'round_over'.Round over
# Player: comp3  Score: 84 Stash Score : 9
# Player: comp2  Score: 86 Stash Score : 11
# Player: mrashid1  Score: 48 Stash Score : 0
# Player: amandlek  Score: 64 Stash Score : 15
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 13, 'CardSuit': [7, 2, 4], 'CardRanks': ['S', 'C', 'C'], 'PileRank': '3', 'PileSuit': 'H'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 16, 'CardSuit': [7, 2, 4, 3], 'CardRanks': ['S', 'C', 'C', 'H']}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 9, 'CardSuit': [2, 4, 3], 'CardRanks': ['C', 'C', 'H'], 'PileRank': '3', 'PileSuit': 'D'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 12, 'CardSuit': [2, 4, 3, 3], 'CardRanks': ['C', 'C', 'H', 'D'], 'PileRank': '2', 'PileSuit': 'D'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 10, 'CardSuit': [4, 3, 3], 'CardRanks': ['C', 'H', 'D'], 'PileRank': '2', 'PileSuit': 'H'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 12, 'CardSuit': [4, 3, 3, 2], 'CardRanks': ['C', 'H', 'D', 'H'], 'PileRank': '4', 'PileSuit': 'H'}
# action drop 0
# b'round_over'.Round over
# Player: comp3  Score: 84 Stash Score : 0
# Player: amandlek  Score: 72 Stash Score : 8
# Player: comp2  Score: 98 Stash Score : 12
# Player: mrashid1  Score: 63 Stash Score : 15
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 6, 'CardSuit': [1, 1, 4], 'CardRanks': ['D', 'S', 'H'], 'PileRank': '4', 'PileSuit': 'C'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 10, 'CardSuit': [1, 1, 4, 4], 'CardRanks': ['D', 'S', 'H', 'C']}
# action drop 0
# b'round_over'.Round over
# Player: comp2  Score: 112 Stash Score : 14
# Player: amandlek  Score: 81 Stash Score : 9
# Player: mrashid1  Score: 79 Stash Score : 16
# Player: comp3  Score: 84 Stash Score : 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 18, 'CardSuit': [7, 6, 5], 'CardRanks': ['D', 'D', 'H'], 'PileRank': '4', 'PileSuit': 'D'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 22, 'CardSuit': [7, 6, 5, 4], 'CardRanks': ['D', 'D', 'H', 'D'], 'PileRank': '3', 'PileSuit': 'C'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 15, 'CardSuit': [6, 5, 4], 'CardRanks': ['D', 'H', 'D'], 'PileRank': '5', 'PileSuit': 'D'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 20, 'CardSuit': [6, 5, 4, 5], 'CardRanks': ['D', 'H', 'D', 'D'], 'PileRank': '7', 'PileSuit': 'H'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 14, 'CardSuit': [5, 4, 5], 'CardRanks': ['H', 'D', 'D'], 'PileRank': '3', 'PileSuit': 'S'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 17, 'CardSuit': [5, 4, 5, 3], 'CardRanks': ['H', 'D', 'D', 'S'], 'PileRank': 'A', 'PileSuit': 'C'}
# action drop 0
# b'round_over'.Round over
# Player: mrashid1  Score: 79 Stash Score : 0
# Player: comp3  Score: 104 Stash Score : 20
# Player: amandlek  Score: 93 Stash Score : 12
# Player: comp2  Score: 127 Stash Score : 15
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 13, 'CardSuit': [7, 4, 2], 'CardRanks': ['D', 'S', 'S'], 'PileRank': '6', 'PileSuit': 'S'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 19, 'CardSuit': [7, 4, 2, 6], 'CardRanks': ['D', 'S', 'S', 'S']}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 12, 'CardSuit': [4, 2, 6], 'CardRanks': ['S', 'S', 'S'], 'PileRank': '6', 'PileSuit': 'C'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 18, 'CardSuit': [4, 2, 6, 6], 'CardRanks': ['S', 'S', 'S', 'C'], 'PileRank': '5', 'PileSuit': 'C'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 14, 'CardSuit': [2, 6, 6], 'CardRanks': ['S', 'S', 'C'], 'PileRank': '4', 'PileSuit': 'D'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 18, 'CardSuit': [2, 6, 6, 4], 'CardRanks': ['S', 'S', 'C', 'D'], 'PileRank': '4', 'PileSuit': 'S'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 16, 'CardSuit': [6, 6, 4], 'CardRanks': ['S', 'C', 'D'], 'PileRank': '7', 'PileSuit': 'H'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 23, 'CardSuit': [6, 6, 4, 7], 'CardRanks': ['S', 'C', 'D', 'H'], 'PileRank': '4', 'PileSuit': 'C'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 17, 'CardSuit': [6, 4, 7], 'CardRanks': ['C', 'D', 'H'], 'PileRank': '7', 'PileSuit': 'C'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 24, 'CardSuit': [6, 4, 7, 7], 'CardRanks': ['C', 'D', 'H', 'C'], 'PileRank': '7', 'PileSuit': 'D'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 18, 'CardSuit': [4, 7, 7], 'CardRanks': ['D', 'H', 'C'], 'PileRank': '5', 'PileSuit': 'D'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 23, 'CardSuit': [4, 7, 7, 5], 'CardRanks': ['D', 'H', 'C', 'D'], 'PileRank': '6', 'PileSuit': 'D'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 19, 'CardSuit': [7, 7, 5], 'CardRanks': ['H', 'C', 'D'], 'PileRank': '3', 'PileSuit': 'H'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 22, 'CardSuit': [7, 7, 5, 3], 'CardRanks': ['H', 'C', 'D', 'H'], 'PileRank': '5', 'PileSuit': 'S'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 15, 'CardSuit': [7, 5, 3], 'CardRanks': ['C', 'D', 'H'], 'PileRank': '5', 'PileSuit': 'H'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 20, 'CardSuit': [7, 5, 3, 5], 'CardRanks': ['C', 'D', 'H', 'H'], 'PileRank': '7', 'PileSuit': 'H'}
# action drop 0
# b'round_over'.Round over
# Player: amandlek  Score: 106 Stash Score : 13
# Player: comp2  Score: 127 Stash Score : 0
# Player: mrashid1  Score: 87 Stash Score : 8
# Player: comp3  Score: 117 Stash Score : 13
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 15, 'CardSuit': [3, 6, 6], 'CardRanks': ['S', 'H', 'C'], 'PileRank': '7', 'PileSuit': 'C'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 22, 'CardSuit': [3, 6, 6, 7], 'CardRanks': ['S', 'H', 'C', 'C']}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 19, 'CardSuit': [6, 6, 7], 'CardRanks': ['H', 'C', 'C'], 'PileRank': 'A', 'PileSuit': 'C'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 20, 'CardSuit': [6, 6, 7, 1], 'CardRanks': ['H', 'C', 'C', 'C'], 'PileRank': 'A', 'PileSuit': 'D'}
# action drop 0
# b'round_over'.Round over
# Player: comp3  Score: 123 Stash Score : 6
# Player: amandlek  Score: 120 Stash Score : 14
# Player: mrashid1  Score: 87 Stash Score : 0
# Player: comp2  Score: 137 Stash Score : 10
# b'round_over'.Round over
# Player: comp3  Score: 134 Stash Score : 11
# Player: mrashid1  Score: 97 Stash Score : 10
# Player: comp2  Score: 137 Stash Score : 0
# Player: amandlek  Score: 131 Stash Score : 11
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 12, 'CardSuit': [4, 7, 1], 'CardRanks': ['D', 'D', 'C'], 'PileRank': '6', 'PileSuit': 'H'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 18, 'CardSuit': [4, 7, 1, 6], 'CardRanks': ['D', 'D', 'C', 'H']}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 14, 'CardSuit': [7, 1, 6], 'CardRanks': ['D', 'C', 'H'], 'PileRank': '7', 'PileSuit': 'C'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 21, 'CardSuit': [7, 1, 6, 7], 'CardRanks': ['D', 'C', 'H', 'C'], 'PileRank': '4', 'PileSuit': 'D'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 14, 'CardSuit': [1, 6, 7], 'CardRanks': ['C', 'H', 'C'], 'PileRank': '6', 'PileSuit': 'D'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 20, 'CardSuit': [1, 6, 7, 6], 'CardRanks': ['C', 'H', 'C', 'D'], 'PileRank': '7', 'PileSuit': 'D'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 19, 'CardSuit': [6, 7, 6], 'CardRanks': ['H', 'C', 'D'], 'PileRank': '7', 'PileSuit': 'H'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 26, 'CardSuit': [6, 7, 6, 7], 'CardRanks': ['H', 'C', 'D', 'H'], 'PileRank': '2', 'PileSuit': 'H'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 20, 'CardSuit': [7, 6, 7], 'CardRanks': ['C', 'D', 'H'], 'PileRank': '6', 'PileSuit': 'S'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 26, 'CardSuit': [7, 6, 7, 6], 'CardRanks': ['C', 'D', 'H', 'S'], 'PileRank': '2', 'PileSuit': 'D'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 19, 'CardSuit': [6, 7, 6], 'CardRanks': ['D', 'H', 'S'], 'PileRank': '3', 'PileSuit': 'H'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 22, 'CardSuit': [6, 7, 6, 3], 'CardRanks': ['D', 'H', 'S', 'H'], 'PileRank': '4', 'PileSuit': 'S'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 16, 'CardSuit': [7, 6, 3], 'CardRanks': ['H', 'S', 'H'], 'PileRank': '5', 'PileSuit': 'H'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 21, 'CardSuit': [7, 6, 3, 5], 'CardRanks': ['H', 'S', 'H', 'H'], 'PileRank': '3', 'PileSuit': 'D'}
# action drop 0
# b'round_over'.Round over
# Player: amandlek  Score: 145 Stash Score : 14
# Player: comp3  Score: 153 Stash Score : 19
# Player: mrashid1  Score: 97 Stash Score : 0
# Player: comp2  Score: 146 Stash Score : 9
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 15, 'CardSuit': [2, 6, 7], 'CardRanks': ['D', 'D', 'C'], 'PileRank': '4', 'PileSuit': 'S'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 19, 'CardSuit': [2, 6, 7, 4], 'CardRanks': ['D', 'D', 'C', 'S'], 'PileRank': '5', 'PileSuit': 'C'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 17, 'CardSuit': [6, 7, 4], 'CardRanks': ['D', 'C', 'S'], 'PileRank': 'A', 'PileSuit': 'C'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 18, 'CardSuit': [6, 7, 4, 1], 'CardRanks': ['D', 'C', 'S', 'C'], 'PileRank': '4', 'PileSuit': 'D'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 12, 'CardSuit': [7, 4, 1], 'CardRanks': ['C', 'S', 'C'], 'PileRank': '5', 'PileSuit': 'H'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 17, 'CardSuit': [7, 4, 1, 5], 'CardRanks': ['C', 'S', 'C', 'H'], 'PileRank': '7', 'PileSuit': 'D'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 10, 'CardSuit': [4, 1, 5], 'CardRanks': ['S', 'C', 'H'], 'PileRank': '4', 'PileSuit': 'H'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 14, 'CardSuit': [4, 1, 5, 4], 'CardRanks': ['S', 'C', 'H', 'H'], 'PileRank': '3', 'PileSuit': 'S'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 10, 'CardSuit': [1, 5, 4], 'CardRanks': ['C', 'H', 'H'], 'PileRank': '2', 'PileSuit': 'S'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 12, 'CardSuit': [1, 5, 4, 2], 'CardRanks': ['C', 'H', 'H', 'S'], 'PileRank': '4', 'PileSuit': 'S'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 11, 'CardSuit': [5, 4, 2], 'CardRanks': ['H', 'H', 'S'], 'PileRank': '6', 'PileSuit': 'S'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 17, 'CardSuit': [5, 4, 2, 6], 'CardRanks': ['H', 'H', 'S', 'S'], 'PileRank': '7', 'PileSuit': 'S'}
# action drop 0
# b'round_over'.Round over
# Player: comp3  Score: 164 Stash Score : 11
# Player: amandlek  Score: 157 Stash Score : 12
# Player: mrashid1  Score: 97 Stash Score : 0
# Player: comp2  Score: 160 Stash Score : 14
# b'round_over'.Round over
# Player: comp2  Score: 160 Stash Score : 0
# Player: mrashid1  Score: 105 Stash Score : 8
# Player: amandlek  Score: 170 Stash Score : 13
# Player: comp3  Score: 178 Stash Score : 14
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 14, 'CardSuit': [5, 3, 6], 'CardRanks': ['H', 'S', 'C'], 'PileRank': 'A', 'PileSuit': 'C'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 15, 'CardSuit': [5, 3, 6, 1], 'CardRanks': ['H', 'S', 'C', 'C']}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 10, 'CardSuit': [3, 6, 1], 'CardRanks': ['S', 'C', 'C'], 'PileRank': '2', 'PileSuit': 'S'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 12, 'CardSuit': [3, 6, 1, 2], 'CardRanks': ['S', 'C', 'C', 'S'], 'PileRank': '7', 'PileSuit': 'D'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 9, 'CardSuit': [6, 1, 2], 'CardRanks': ['C', 'C', 'S'], 'PileRank': '3', 'PileSuit': 'H'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 12, 'CardSuit': [6, 1, 2, 3], 'CardRanks': ['C', 'C', 'S', 'H'], 'PileRank': '3', 'PileSuit': 'S'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 6, 'CardSuit': [1, 2, 3], 'CardRanks': ['C', 'S', 'H'], 'PileRank': '7', 'PileSuit': 'C'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 13, 'CardSuit': [1, 2, 3, 7], 'CardRanks': ['C', 'S', 'H', 'C'], 'PileRank': '6', 'PileSuit': 'S'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 12, 'CardSuit': [2, 3, 7], 'CardRanks': ['S', 'H', 'C'], 'PileRank': '5', 'PileSuit': 'C'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 17, 'CardSuit': [2, 3, 7, 5], 'CardRanks': ['S', 'H', 'C', 'C'], 'PileRank': '5', 'PileSuit': 'S'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 15, 'CardSuit': [3, 7, 5], 'CardRanks': ['H', 'C', 'C'], 'PileRank': 'A', 'PileSuit': 'S'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 16, 'CardSuit': [3, 7, 5, 1], 'CardRanks': ['H', 'C', 'C', 'S'], 'PileRank': '6', 'PileSuit': 'H'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 13, 'CardSuit': [7, 5, 1], 'CardRanks': ['C', 'C', 'S'], 'PileRank': 'A', 'PileSuit': 'H'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 14, 'CardSuit': [7, 5, 1, 1], 'CardRanks': ['C', 'C', 'S', 'H'], 'PileRank': '2', 'PileSuit': 'C'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 7, 'CardSuit': [5, 1, 1], 'CardRanks': ['C', 'S', 'H'], 'PileRank': '3', 'PileSuit': 'D'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 10, 'CardSuit': [5, 1, 1, 3], 'CardRanks': ['C', 'S', 'H', 'D'], 'PileRank': '5', 'PileSuit': 'D'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 5, 'CardSuit': [1, 1, 3], 'CardRanks': ['S', 'H', 'D'], 'PileRank': '3', 'PileSuit': 'C'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 8, 'CardSuit': [1, 1, 3, 3], 'CardRanks': ['S', 'H', 'D', 'C']}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 7, 'CardSuit': [1, 3, 3], 'CardRanks': ['H', 'D', 'C'], 'PileRank': '2', 'PileSuit': 'H'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 9, 'CardSuit': [1, 3, 3, 2], 'CardRanks': ['H', 'D', 'C', 'H'], 'PileRank': 'A', 'PileSuit': 'C'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 8, 'CardSuit': [3, 3, 2], 'CardRanks': ['D', 'C', 'H'], 'PileRank': '7', 'PileSuit': 'S'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 15, 'CardSuit': [3, 3, 2, 7], 'CardRanks': ['D', 'C', 'H', 'S'], 'PileRank': '4', 'PileSuit': 'C'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 12, 'CardSuit': [3, 2, 7], 'CardRanks': ['C', 'H', 'S'], 'PileRank': 'A', 'PileSuit': 'D'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 13, 'CardSuit': [3, 2, 7, 1], 'CardRanks': ['C', 'H', 'S', 'D'], 'PileRank': '3', 'PileSuit': 'D'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 10, 'CardSuit': [2, 7, 1], 'CardRanks': ['H', 'S', 'D'], 'PileRank': '4', 'PileSuit': 'D'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 14, 'CardSuit': [2, 7, 1, 4], 'CardRanks': ['H', 'S', 'D', 'D'], 'PileRank': '3', 'PileSuit': 'C'}
# action drop 0
# b'round_over'.Round over
# Player: comp3  Score: 190 Stash Score : 12
# Player: amandlek  Score: 182 Stash Score : 12
# Player: mrashid1  Score: 105 Stash Score : 0
# Player: comp2  Score: 178 Stash Score : 18
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 15, 'CardSuit': [4, 7, 4], 'CardRanks': ['D', 'H', 'S'], 'PileRank': '3', 'PileSuit': 'S'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 18, 'CardSuit': [4, 7, 4, 3], 'CardRanks': ['D', 'H', 'S', 'S']}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 14, 'CardSuit': [7, 4, 3], 'CardRanks': ['H', 'S', 'S'], 'PileRank': '6', 'PileSuit': 'D'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 20, 'CardSuit': [7, 4, 3, 6], 'CardRanks': ['H', 'S', 'S', 'D'], 'PileRank': '7', 'PileSuit': 'C'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 13, 'CardSuit': [4, 3, 6], 'CardRanks': ['S', 'S', 'D'], 'PileRank': '7', 'PileSuit': 'S'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 20, 'CardSuit': [4, 3, 6, 7], 'CardRanks': ['S', 'S', 'D', 'S'], 'PileRank': '7', 'PileSuit': 'H'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 16, 'CardSuit': [3, 6, 7], 'CardRanks': ['S', 'D', 'S'], 'PileRank': '6', 'PileSuit': 'S'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 22, 'CardSuit': [3, 6, 7, 6], 'CardRanks': ['S', 'D', 'S', 'S'], 'PileRank': '7', 'PileSuit': 'D'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 19, 'CardSuit': [6, 7, 6], 'CardRanks': ['D', 'S', 'S'], 'PileRank': '5', 'PileSuit': 'H'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 24, 'CardSuit': [6, 7, 6, 5], 'CardRanks': ['D', 'S', 'S', 'H'], 'PileRank': '6', 'PileSuit': 'H'}
# action drop 0
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 18, 'CardSuit': [7, 6, 5], 'CardRanks': ['S', 'S', 'H'], 'PileRank': '4', 'PileSuit': 'H'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 22, 'CardSuit': [7, 6, 5, 4], 'CardRanks': ['S', 'S', 'H', 'H'], 'PileRank': '6', 'PileSuit': 'D'}
# action drop 0
# b'round_over'.Round over
# Player: amandlek  Score: 197 Stash Score : 15
# Player: mrashid1  Score: 105 Stash Score : 0
# Player: comp3  Score: 201 Stash Score : 11
# Player: comp2  Score: 189 Stash Score : 11
# b'sendinfo'.sendinfo
# sendinfo
# {'Stash Score': 10, 'CardSuit': [2, 6, 2], 'CardRanks': ['S', 'H', 'C'], 'PileRank': '2', 'PileSuit': 'H'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 6, 'CardSuit': [6], 'CardRanks': ['H'], 'PileRank': '6', 'PileSuit': 'C'}
# action drop 0
# b'round_over'.Round over
# Player: comp2  Score: 207 Stash Score : 18
# Player: amandlek  Score: 197 Stash Score : 0
# Player: mrashid1  Score: 117 Stash Score : 12
# Player: comp3  Score: 208 Stash Score : 7
# b'gameover'.Game over wait for others to play and wait for results
